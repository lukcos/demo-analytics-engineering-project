# %%
import polars as pl 
import json

file_path = "sample_data/receipts.json"

with open(file_path, 'r') as file:
    data = json.load(file)


# df = pl.DataFrame(data)

# %%
# pl.json_normalize(data).unnest("rewardsReceiptItemList")

# pl.json_normalize(data).explode("rewardsReceiptItemList")

schema={
    "_id": pl.String()
}

pl.DataFrame(data).explode("rewardsReceiptItemList")
# Out:
# shape: (7_381, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ _id       ┆ bonusPoin ┆ bonusPoin ┆ createDat ┆ … ┆ rewardsRe ┆ rewardsRe ┆ totalSpen ┆ userId   │
# │ ---       ┆ tsEarned  ┆ tsEarnedR ┆ e         ┆   ┆ ceiptItem ┆ ceiptStat ┆ t         ┆ ---      │
# │ struct[1] ┆ ---       ┆ eason     ┆ ---       ┆   ┆ List      ┆ us        ┆ ---       ┆ str      │
# │           ┆ i64       ┆ ---       ┆ struct[1] ┆   ┆ ---       ┆ ---       ┆ str       ┆          │
# │           ┆           ┆ str       ┆           ┆   ┆ struct[33 ┆ str       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ ]         ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ {"5ff1e1e ┆ 500       ┆ Receipt   ┆ {16096875 ┆ … ┆ {"4011"," ┆ FINISHED  ┆ 26.00     ┆ 5ff1e1ea │
# │ b0a720f05 ┆           ┆ number 2  ┆ 31000}    ┆   ┆ ITEM NOT  ┆           ┆           ┆ cfcf6c39 │
# │ 23000575" ┆           ┆ completed ┆           ┆   ┆ FOUND","2 ┆           ┆           ┆ 9c274ae6 │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆ 6.0…      ┆           ┆           ┆          │
# │ {"5ff1e1b ┆ 150       ┆ Receipt   ┆ {16096874 ┆ … ┆ {"4011"," ┆ FINISHED  ┆ 11.00     ┆ 5ff1e194 │
# │ b0a720f05 ┆           ┆ number 5  ┆ 83000}    ┆   ┆ ITEM NOT  ┆           ┆           ┆ b6a9d73a │
# │ 2300056b" ┆           ┆ completed ┆           ┆   ┆ FOUND","1 ┆           ┆           ┆ 3a9f1052 │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆ ","…      ┆           ┆           ┆          │
# │ {"5ff1e1b ┆ 150       ┆ Receipt   ┆ {16096874 ┆ … ┆ {"0284006 ┆ FINISHED  ┆ 11.00     ┆ 5ff1e194 │
# │ b0a720f05 ┆           ┆ number 5  ┆ 83000}    ┆   ┆ 42255","D ┆           ┆           ┆ b6a9d73a │
# │ 2300056b" ┆           ┆ completed ┆           ┆   ┆ ORITOS    ┆           ┆           ┆ 3a9f1052 │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆ TORTI…    ┆           ┆           ┆          │
# │ {"5ff1e1f ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ {null,nul ┆ REJECTED  ┆ 10.00     ┆ 5ff1e1f1 │
# │ 10a720f05 ┆           ┆ pts       ┆ 37000}    ┆   ┆ l,null,nu ┆           ┆           ┆ cfcf6c39 │
# │ 2300057a" ┆           ┆ receipt   ┆           ┆   ┆ ll,false, ┆           ┆           ┆ 9c274b0b │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆ nul…      ┆           ┆           ┆          │
# │ {"5ff1e1e ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ {"4011"," ┆ FINISHED  ┆ 28.00     ┆ 5ff1e1ea │
# │ e0a7214ad ┆           ┆ pts       ┆ 34000}    ┆   ┆ ITEM NOT  ┆           ┆           ┆ cfcf6c39 │
# │ a100056f" ┆           ┆ receipt   ┆           ┆   ┆ FOUND","2 ┆           ┆           ┆ 9c274ae6 │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆ 8.0…      ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ {"603d0b7 ┆ null      ┆ null      ┆ {16146133 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ 10a720fde ┆           ┆           ┆ 61873}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 1000042a" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603cf52 ┆ null      ┆ null      ┆ {16146076 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ 90a720fde ┆           ┆           ┆ 57664}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 10000413" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603ce71 ┆ 25        ┆ COMPLETE_ ┆ {16146040 ┆ … ┆ {"B076FJ9 ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ 00a7217c7 ┆           ┆ NONPARTNE ┆ 48000}    ┆   ┆ 2M4","mue ┆           ┆           ┆ b8cfca11 │
# │ 2c000405" ┆           ┆ R_RECEIPT ┆           ┆   ┆ ller      ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆ austria…  ┆           ┆           ┆          │
# │ {"603ce71 ┆ 25        ┆ COMPLETE_ ┆ {16146040 ┆ … ┆ {"B07BRRL ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ 00a7217c7 ┆           ┆ NONPARTNE ┆ 48000}    ┆   ┆ SVC","thi ┆           ┆           ┆ b8cfca11 │
# │ 2c000405" ┆           ┆ R_RECEIPT ┆           ┆   ┆ ndust     ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆ summer…   ┆           ┆           ┆          │
# │ {"603c4fe ┆ null      ┆ null      ┆ {16145653 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ a0a7217c7 ┆           ┆           ┆ 54962}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 2c000389" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df.schema
# Out:
# Schema([('_id', Struct({'$oid': String})),
#         ('bonusPointsEarned', Int64),
#         ('bonusPointsEarnedReason', String),
#         ('createDate', Struct({'$date': Int64})),
#         ('dateScanned', Struct({'$date': Int64})),
#         ('finishedDate', Struct({'$date': Int64})),
#         ('modifyDate', Struct({'$date': Int64})),
#         ('pointsAwardedDate', Struct({'$date': Int64})),
#         ('pointsEarned', String),
#         ('purchaseDate', Struct({'$date': Int64})),
#         ('purchasedItemCount', Int64),
#         ('rewardsReceiptItemList',
#          List(Struct({'barcode': String, 'description': String, 'finalPrice': String, 'itemPrice': String, 'needsFetchReview': Boolean, 'needsFetchReviewReason': String, 'partnerItemId': String, 'pointsNotAwardedReason': String, 'pointsPayerId': String, 'preventTargetGapPoints': Boolean, 'quantityPurchased': Int64, 'rewardsGroup': String, 'rewardsProductPartnerId': String, 'userFlaggedBarcode': String, 'userFlaggedDescription': String, 'userFlaggedNewItem': Boolean, 'userFlaggedPrice': String, 'userFlaggedQuantity': Int64, 'originalMetaBriteBarcode': String, 'originalMetaBriteDescription': String, 'brandCode': String, 'competitorRewardsGroup': String, 'discountedItemPrice': String, 'originalReceiptItemText': String, 'itemNumber': String, 'originalMetaBriteQuantityPurchased': Int64, 'pointsEarned': String, 'targetPrice': String, 'competitiveProduct': Boolean, 'originalFinalPrice': String, 'originalMetaBriteItemPrice': String, 'deleted': Boolean, 'priceAfterCoupon': String}))),
#         ('rewardsReceiptStatus', String),
#         ('totalSpent', String),
#         ('userId', String)])

# %%
# df.with_columns(
#     struct=pl.col("rewardsReceiptItemList").list.to_struct(fields=["barcode", "description"])
# )

# .unnest("rewardsReceiptItemList")


# schema = {'barcode': pl.String(), 'description': String, 'finalPrice': String, 'itemPrice': String, 'needsFetchReview': Boolean, 'needsFetchReviewReason': String, 'partnerItemId': String, 'pointsNotAwardedReason': String, 'pointsPayerId': String, 'preventTargetGapPoints': Boolean, 'quantityPurchased': Int64, 'rewardsGroup': String, 'rewardsProductPartnerId': String, 'userFlaggedBarcode': String, 'userFlaggedDescription': String, 'userFlaggedNewItem': Boolean, 'userFlaggedPrice': String, 'userFlaggedQuantity': Int64, 'originalMetaBriteBarcode': String, 'originalMetaBriteDescription': String, 'brandCode': String, 'competitorRewardsGroup': String, 'discountedItemPrice': String, 'originalReceiptItemText': String, 'itemNumber': String, 'originalMetaBriteQuantityPurchased': Int64, 'pointsEarned': String, 'targetPrice': String, 'competitiveProduct': Boolean, 'originalFinalPrice': String, 'originalMetaBriteItemPrice': String, 'deleted': Boolean, 'priceAfterCoupon': String}
# df.schema
# Out:
# shape: (1_119, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ _id       ┆ bonusPoin ┆ bonusPoin ┆ createDat ┆ … ┆ rewardsRe ┆ totalSpen ┆ userId    ┆ struct   │
# │ ---       ┆ tsEarned  ┆ tsEarnedR ┆ e         ┆   ┆ ceiptStat ┆ t         ┆ ---       ┆ ---      │
# │ struct[1] ┆ ---       ┆ eason     ┆ ---       ┆   ┆ us        ┆ ---       ┆ str       ┆ struct[2 │
# │           ┆ i64       ┆ ---       ┆ struct[1] ┆   ┆ ---       ┆ str       ┆           ┆ ]        │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ {"5ff1e1e ┆ 500       ┆ Receipt   ┆ {16096875 ┆ … ┆ FINISHED  ┆ 26.00     ┆ 5ff1e1eac ┆ {{"4011" │
# │ b0a720f05 ┆           ┆ number 2  ┆ 31000}    ┆   ┆           ┆           ┆ fcf6c399c ┆ ,"ITEM   │
# │ 23000575" ┆           ┆ completed ┆           ┆   ┆           ┆           ┆ 274ae6    ┆ NOT FOUN │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆           ┆           ┆           ┆ D","26.… │
# │ {"5ff1e1b ┆ 150       ┆ Receipt   ┆ {16096874 ┆ … ┆ FINISHED  ┆ 11.00     ┆ 5ff1e194b ┆ {{"4011" │
# │ b0a720f05 ┆           ┆ number 5  ┆ 83000}    ┆   ┆           ┆           ┆ 6a9d73a3a ┆ ,"ITEM   │
# │ 2300056b" ┆           ┆ completed ┆           ┆   ┆           ┆           ┆ 9f1052    ┆ NOT FOUN │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆           ┆           ┆           ┆ D","1",… │
# │ {"5ff1e1f ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ REJECTED  ┆ 10.00     ┆ 5ff1e1f1c ┆ {{null,n │
# │ 10a720f05 ┆           ┆ pts       ┆ 37000}    ┆   ┆           ┆           ┆ fcf6c399c ┆ ull,null │
# │ 2300057a" ┆           ┆ receipt   ┆           ┆   ┆           ┆           ┆ 274b0b    ┆ ,null,fa │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆ lse,nu…  │
# │ {"5ff1e1e ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ FINISHED  ┆ 28.00     ┆ 5ff1e1eac ┆ {{"4011" │
# │ e0a7214ad ┆           ┆ pts       ┆ 34000}    ┆   ┆           ┆           ┆ fcf6c399c ┆ ,"ITEM   │
# │ a100056f" ┆           ┆ receipt   ┆           ┆   ┆           ┆           ┆ 274ae6    ┆ NOT FOUN │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆ D","28.… │
# │ {"5ff1e1d ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ FINISHED  ┆ 1.00      ┆ 5ff1e194b ┆ {{"4011" │
# │ 20a7214ad ┆           ┆ pts       ┆ 06000}    ┆   ┆           ┆           ┆ 6a9d73a3a ┆ ,"ITEM   │
# │ a1000561" ┆           ┆ receipt   ┆           ┆   ┆           ┆           ┆ 9f1052    ┆ NOT FOUN │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆ D","1",… │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ {"603cc06 ┆ 25        ┆ COMPLETE_ ┆ {16145941 ┆ … ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3b ┆ {{"B076F │
# │ 30a720fde ┆           ┆ NONPARTNE ┆ 47000}    ┆   ┆           ┆           ┆ 8cfca11a0 ┆ J92M4"," │
# │ 100003e6" ┆           ┆ R_RECEIPT ┆           ┆   ┆           ┆           ┆ 77dd33    ┆ mueller  │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ austri…  │
# │ {"603d0b7 ┆ null      ┆ null      ┆ {16146133 ┆ … ┆ SUBMITTED ┆ null      ┆ 5fc961c3b ┆ {null,nu │
# │ 10a720fde ┆           ┆           ┆ 61873}    ┆   ┆           ┆           ┆ 8cfca11a0 ┆ ll}      │
# │ 1000042a" ┆           ┆           ┆           ┆   ┆           ┆           ┆ 77dd33    ┆          │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603cf52 ┆ null      ┆ null      ┆ {16146076 ┆ … ┆ SUBMITTED ┆ null      ┆ 5fc961c3b ┆ {null,nu │
# │ 90a720fde ┆           ┆           ┆ 57664}    ┆   ┆           ┆           ┆ 8cfca11a0 ┆ ll}      │
# │ 10000413" ┆           ┆           ┆           ┆   ┆           ┆           ┆ 77dd33    ┆          │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603ce71 ┆ 25        ┆ COMPLETE_ ┆ {16146040 ┆ … ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3b ┆ {{"B076F │
# │ 00a7217c7 ┆           ┆ NONPARTNE ┆ 48000}    ┆   ┆           ┆           ┆ 8cfca11a0 ┆ J92M4"," │
# │ 2c000405" ┆           ┆ R_RECEIPT ┆           ┆   ┆           ┆           ┆ 77dd33    ┆ mueller  │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ austri…  │
# │ {"603c4fe ┆ null      ┆ null      ┆ {16145653 ┆ … ┆ SUBMITTED ┆ null      ┆ 5fc961c3b ┆ {null,nu │
# │ a0a7217c7 ┆           ┆           ┆ 54962}    ┆   ┆           ┆           ┆ 8cfca11a0 ┆ ll}      │
# │ 2c000389" ┆           ┆           ┆           ┆   ┆           ┆           ┆ 77dd33    ┆          │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
schema = {
'receipt_id': pl.String(),
'barcode': pl.String(), 
'description': pl.String(), 
'finalPrice': pl.String(), 
'itemPrice': pl.String(), 
'needsFetchReview': pl.Boolean(), 
'needsFetchReviewReason': pl.String(), 
'partnerItemId': pl.String(), 
'pointsNotAwardedReason': pl.String(), 
'pointsPayerId': pl.String(), 
'preventTargetGapPoints': pl.Boolean(), 
'quantityPurchased': pl.Int64, 
'rewardsGroup': pl.String(), 
'rewardsProductPartnerId': pl.String(), 
'userFlaggedBarcode': pl.String(), 
'userFlaggedDescription': pl.String(), 
'userFlaggedNewItem': pl.Boolean(), 
'userFlaggedPrice': pl.String(), 
'userFlaggedQuantity': pl.Int64, 
'originalMetaBriteBarcode': pl.String(), 
'originalMetaBriteDescription': pl.String(), 
'brandCode': pl.String(), 
'competitorRewardsGroup': pl.String(), 
'discountedItemPrice': pl.String(), 
'originalReceiptItemText': pl.String(), 
'itemNumber': pl.String(), 
'originalMetaBriteQuantityPurchased': pl.Int64, 
'pointsEarned': pl.String(), 
'targetPrice': pl.String(), 
'competitiveProduct': pl.Boolean(), 
'originalFinalPrice': pl.String(), 
'originalMetaBriteItemPrice': pl.String(), 
'deleted': pl.Boolean(), 
'priceAfterCoupon': pl.String()
}

receipt_df = pl.DataFrame([], schema=schema)

for i in range(len(data)):
    try:
        if cleaned_data[i]["rewardsReceiptItemList"] != None:
            receipt_df1 = pl.DataFrame(cleaned_data[i]["rewardsReceiptItemList"], schema=schema)
            receipt_df1 = receipt_df1.with_columns(
                pl.lit(cleaned_data[i]["_id"]["$oid"]).alias("receipt_id")
            )
            receipt_df = pl.concat([receipt_df, receipt_df1])
        else: 
            pass
    except:
        pass

receipt_df
# Out:
# shape: (6_941, 34)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ receipt_id ┆ barcode   ┆ descripti ┆ finalPric ┆ … ┆ originalF ┆ originalM ┆ deleted ┆ priceAfte │
# │ ---        ┆ ---       ┆ on        ┆ e         ┆   ┆ inalPrice ┆ etaBriteI ┆ ---     ┆ rCoupon   │
# │ str        ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ temPrice  ┆ bool    ┆ ---       │
# │            ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆         ┆ str       │
# │            ┆           ┆           ┆           ┆   ┆           ┆ str       ┆         ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 5ff1e1eb0a ┆ 4011      ┆ ITEM NOT  ┆ 26.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆           ┆ FOUND     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0575       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff1e1bb0a ┆ 4011      ┆ ITEM NOT  ┆ 1         ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆           ┆ FOUND     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 056b       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff1e1bb0a ┆ 028400642 ┆ DORITOS   ┆ 10.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆ 255       ┆ TORTILLA  ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 056b       ┆           ┆ CHIP      ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ SPICY SW… ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff1e1f10a ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 057a       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff1e1ee0a ┆ 4011      ┆ ITEM NOT  ┆ 28.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ada100 ┆           ┆ FOUND     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 056f       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …       ┆ …         │
# │ 603cc2bc0a ┆ B07BRRLSV ┆ thindust  ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null    ┆ 11.99     │
# │ 720fde1000 ┆ C         ┆ summer    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 03e9       ┆           ┆ face mask ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ - su…     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 603cc0630a ┆ B076FJ92M ┆ mueller   ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null    ┆ 22.97     │
# │ 720fde1000 ┆ 4         ┆ austria   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 03e6       ┆           ┆ hypergrin ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ d pre…    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 603cc0630a ┆ B07BRRLSV ┆ thindust  ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null    ┆ 11.99     │
# │ 720fde1000 ┆ C         ┆ summer    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 03e6       ┆           ┆ face mask ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ - su…     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 603ce7100a ┆ B076FJ92M ┆ mueller   ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null    ┆ 22.97     │
# │ 7217c72c00 ┆ 4         ┆ austria   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0405       ┆           ┆ hypergrin ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ d pre…    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 603ce7100a ┆ B07BRRLSV ┆ thindust  ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null    ┆ 11.99     │
# │ 7217c72c00 ┆ C         ┆ summer    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0405       ┆           ┆ face mask ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ - su…     ┆           ┆   ┆           ┆           ┆         ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %%
receipt_df.filter(
    pl.col("brandCode").is_not_null()
)
# Out:
# shape: (2_600, 34)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ receipt_id ┆ barcode   ┆ descripti ┆ finalPric ┆ … ┆ originalF ┆ originalM ┆ deleted ┆ priceAfte │
# │ ---        ┆ ---       ┆ on        ┆ e         ┆   ┆ inalPrice ┆ etaBriteI ┆ ---     ┆ rCoupon   │
# │ str        ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ temPrice  ┆ bool    ┆ ---       │
# │            ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆         ┆ str       │
# │            ┆           ┆           ┆           ┆   ┆           ┆ str       ┆         ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 5ff1e1cd0a ┆ null      ┆ MSSN      ┆ 2.23      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆           ┆ TORTLLA   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 056f       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff1e1a40a ┆ 046000832 ┆ Old El    ┆ 10.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f052300 ┆ 517       ┆ Paso Mild ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0569       ┆           ┆ Chopped   ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ Green…    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff29be20a ┆ 044000000 ┆ -Cheddar  ┆ 1.00      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ada100 ┆ 745       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0571       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff618e30a ┆ 012000809 ┆ REGULAR   ┆ 1.96      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ada100 ┆ 941       ┆ PEPSI     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 05fa       ┆           ┆ SODA COLA ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ CAN 12…   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 5ff618e30a ┆ 028400642 ┆ DORITOS   ┆ 6.90      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ada100 ┆ 033       ┆ TORTILLA  ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 05fa       ┆           ┆ CHIP      ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ NACHO CH… ┆           ┆   ┆           ┆           ┆         ┆           │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …       ┆ …         │
# │ 60189cc10a ┆ 070470149 ┆ Yoplait   ┆ 10.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ad2800 ┆ 394       ┆ Fiber One ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0050       ┆           ┆ Non-Fat   ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ Yogu…     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 60189cae0a ┆ null      ┆ MSSN      ┆ 2.23      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214ad2800 ┆           ┆ TORTLLA   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 004f       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 602454340a ┆ 036000494 ┆ VIVA      ┆ 3.92      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 720f05a800 ┆ 129       ┆ PAPER     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 01ae       ┆           ┆ TOWEL 1   ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ PACK 2    ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ COUN…     ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 602538b30a ┆ 042800108 ┆ Totino's  ┆ 10.00     ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214d8e900 ┆ 005       ┆ Triple    ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0248       ┆           ┆ Meat      ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ Party     ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆           ┆ Piz…      ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 602538740a ┆ null      ┆ MSSN      ┆ 2.23      ┆ … ┆ null      ┆ null      ┆ null    ┆ null      │
# │ 7214d8e900 ┆           ┆ TORTLLA   ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0246       ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %%
receipt_df.filter(
    pl.col("originalMetaBriteItemPrice").is_not_null()
)
# Out:
# shape: (9, 33)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ barcode    ┆ descripti ┆ finalPric ┆ itemPrice ┆ … ┆ originalF ┆ originalM ┆ deleted ┆ priceAfte │
# │ ---        ┆ on        ┆ e         ┆ ---       ┆   ┆ inalPrice ┆ etaBriteI ┆ ---     ┆ rCoupon   │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ temPrice  ┆ bool    ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ str       ┆ ---       ┆         ┆ str       │
# │            ┆           ┆           ┆           ┆   ┆           ┆ str       ┆         ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 0759253062 ┆ null      ┆ 10.00     ┆ 10.00     ┆ … ┆ 10.00     ┆ 10.00     ┆ null    ┆ null      │
# │ 54         ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0759253062 ┆ null      ┆ 10.00     ┆ 10.00     ┆ … ┆ 10.00     ┆ 10.00     ┆ null    ┆ null      │
# │ 54         ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0759253062 ┆ null      ┆ 10.00     ┆ 10.00     ┆ … ┆ 10.00     ┆ 10.00     ┆ null    ┆ null      │
# │ 54         ┆           ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │ 0341005730 ┆ MILLER    ┆ 1.00      ┆ 1.00      ┆ … ┆ 1.00      ┆ 1.00      ┆ null    ┆ null      │
# │ 65         ┆ LITE 24   ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ PACK 12OZ ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# │            ┆ CAN       ┆           ┆           ┆   ┆           ┆           ┆         ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %%
data[499]["_id"]["$oid"]
# Out:
# '6010be5a0a720f053500005a'

# %%
def remove_null_values(json_object):
    if isinstance(json_object, dict):
        return {k: remove_null_values(v) for k, v in json_object.items() if v is not None}
    elif isinstance(json_object, list):
        return [remove_null_values(item) for item in json_object if item is not None]
    else:
        return json_object

cleaned_data = remove_null_values(data)

# %%
data[0]
# Out:
# {'_id': {'$oid': '5ff1e1eb0a720f0523000575'},
#  'bonusPointsEarned': 500,
#  'bonusPointsEarnedReason': 'Receipt number 2 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)',
#  'createDate': {'$date': 1609687531000},
#  'dateScanned': {'$date': 1609687531000},
#  'finishedDate': {'$date': 1609687531000},
#  'modifyDate': {'$date': 1609687536000},
#  'pointsAwardedDate': {'$date': 1609687531000},
#  'pointsEarned': '500.0',
#  'purchaseDate': {'$date': 1609632000000},
#  'purchasedItemCount': 5,
#  'rewardsReceiptItemList': [{'barcode': '4011',
#    'description': 'ITEM NOT FOUND',
#    'finalPrice': '26.00',
#    'itemPrice': '26.00',
#    'needsFetchReview': False,
#    'partnerItemId': '1',
#    'preventTargetGapPoints': True,
#    'quantityPurchased': 5,
#    'userFlaggedBarcode': '4011',
#    'userFlaggedNewItem': True,
#    'userFlaggedPrice': '26.00',
#    'userFlaggedQuantity': 5}],
#  'rewardsReceiptStatus': 'FINISHED',
#  'totalSpent': '26.00',
#  'userId': '5ff1e1eacfcf6c399c274ae6'}

# %%
import polars as pl
import json
from typing import Dict, Any, List

def load_json_data(file_path: str) -> List[Dict[str, Any]]:
    """Load JSON data from file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def extract_receipt_items(data: List[Dict[str, Any]]) -> pl.DataFrame:
    """
    Extract all receipt items from the nested JSON structure.
    This function automatically preserves all fields from the nested items.
    """
    # Initialize empty list to store all items
    all_items = []
    
    # Process each receipt
    for receipt in data:
        # Skip if receipt doesn't have item list or it's None
        if "rewardsReceiptItemList" not in receipt or receipt["rewardsReceiptItemList"] is None:
            continue
            
        # Get receipt ID
        receipt_id = receipt.get("_id", {}).get("$oid", None)
        if not receipt_id:
            continue
            
        # Process each item in the receipt
        for item in receipt["rewardsReceiptItemList"]:
            # Add receipt_id to each item
            item_with_id = item.copy()
            item_with_id["receipt_id"] = receipt_id
            all_items.append(item_with_id)
    
    # Return empty DataFrame if no items found
    if not all_items:
        return pl.DataFrame()
    
    # Convert to DataFrame - Polars will infer the schema automatically
    return pl.from_dicts(all_items).lazy()

def process_receipts_file(file_path: str) -> pl.DataFrame:
    """Process receipts file and return items DataFrame."""
    # Load data
    data = load_json_data(file_path)
    
    # Extract items
    items_lf = extract_receipt_items(data)
    
    # Convert string columns that should be numeric
    numeric_cols = ["finalPrice", "itemPrice", "discountedItemPrice", 
                    "targetPrice", "priceAfterCoupon", "pointsEarned"]
    
    # Only convert columns that actually exist in the data
    for col in set(numeric_cols).intersection(set(items_lf.collect_schema().names())):
        items_lf = items_lf.with_columns(
            pl.col(col).str.replace("$", "").cast(pl.Float64, strict=False).alias(col)
        )
    
    return items_lf

file_path = "sample_data/receipts.json"
receipt_df = process_receipts_file(file_path)
receipt_df.collect()
# Out:
# shape: (6_941, 33)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬─────────┐
# │ barcode    ┆ descripti ┆ finalPric ┆ itemPrice ┆ … ┆ competiti ┆ originalF ┆ originalM ┆ deleted │
# │ ---        ┆ on        ┆ e         ┆ ---       ┆   ┆ veProduct ┆ inalPrice ┆ etaBriteI ┆ ---     │
# │ str        ┆ ---       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ temPrice  ┆ bool    │
# │            ┆ str       ┆ f64       ┆           ┆   ┆ bool      ┆ str       ┆ ---       ┆         │
# │            ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆         │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═════════╡
# │ 4011       ┆ ITEM NOT  ┆ 26.0      ┆ 26.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ 4011       ┆ ITEM NOT  ┆ 1.0       ┆ 1.0       ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ 0284006422 ┆ DORITOS   ┆ 10.0      ┆ 10.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │ 55         ┆ TORTILLA  ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ CHIP      ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ SPICY SW… ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ null       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │ 4011       ┆ ITEM NOT  ┆ 28.0      ┆ 28.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …       │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B076FJ92M4 ┆ mueller   ┆ 22.97     ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ austria   ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ hypergrin ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ d pre…    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B076FJ92M4 ┆ mueller   ┆ 22.97     ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ austria   ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ hypergrin ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ d pre…    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴─────────┘

# %%
data = load_json_data(file_path)

extract_receipt_items(data)
# Out:
# shape: (6_941, 33)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬─────────┐
# │ barcode    ┆ descripti ┆ finalPric ┆ itemPrice ┆ … ┆ competiti ┆ originalF ┆ originalM ┆ deleted │
# │ ---        ┆ on        ┆ e         ┆ ---       ┆   ┆ veProduct ┆ inalPrice ┆ etaBriteI ┆ ---     │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ ---       ┆ temPrice  ┆ bool    │
# │            ┆ str       ┆ str       ┆           ┆   ┆ bool      ┆ str       ┆ ---       ┆         │
# │            ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆         │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═════════╡
# │ 4011       ┆ ITEM NOT  ┆ 26.00     ┆ 26.00     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ 4011       ┆ ITEM NOT  ┆ 1         ┆ 1         ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ 0284006422 ┆ DORITOS   ┆ 10.00     ┆ 10.00     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │ 55         ┆ TORTILLA  ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ CHIP      ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ SPICY SW… ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ null       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │ 4011       ┆ ITEM NOT  ┆ 28.00     ┆ 28.00     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ FOUND     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …       │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B076FJ92M4 ┆ mueller   ┆ 22.97     ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ austria   ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ hypergrin ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ d pre…    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B076FJ92M4 ┆ mueller   ┆ 22.97     ┆ 22.97     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ austria   ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ hypergrin ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ d pre…    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │ B07BRRLSVC ┆ thindust  ┆ 11.99     ┆ 11.99     ┆ … ┆ null      ┆ null      ┆ null      ┆ null    │
# │            ┆ summer    ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ face mask ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# │            ┆ - su…     ┆           ┆           ┆   ┆           ┆           ┆           ┆         │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴─────────┘

# %%
2600/(2600+4341)
# Out:
# 0.37458579455409885

# %%
def load_json_data(file_path: str) -> List[Dict[str, Any]]:
    """Load JSON data from file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def extract_data(data: List[Dict[str, Any]]) -> pl.DataFrame:
    """
    Extract all receipts data from the original JSON.
    This function automatically preserves all fields from the nested items.
    """
    # Initialize empty list to store all items
    all_items = []
    
    # Process each receipt
    for receipt in data:
        # Skip if receipt doesn't have item list or it's None
        if "rewardsReceiptItemList" not in receipt or receipt["rewardsReceiptItemList"] is None:
            continue
            
        # Get receipt ID
        receipt_id = receipt.get("_id", {}).get("$oid", None)
        if not receipt_id:
            continue
            
        # Process each item in the receipt
        for item in receipt["rewardsReceiptItemList"]:
            # Add receipt_id to each item
            item_with_id = item.copy()
            item_with_id["receipt_id"] = receipt_id
            all_items.append(item_with_id)
    
    # Return empty DataFrame if no items found
    if not all_items:
        return pl.DataFrame()
    
    # Convert to DataFrame - Polars will infer the schema automatically
    return pl.from_dicts(all_items).lazy()

def process_receipts_file(file_path: str) -> pl.DataFrame:
    """Process receipts file and return items DataFrame."""
    # Load data
    data = load_json_data(file_path)
    
    # Extract items
    items_lf = extract_receipt_items(data)
    
    # Convert string columns that should be numeric
    numeric_cols = ["finalPrice", "itemPrice", "discountedItemPrice", 
                    "targetPrice", "priceAfterCoupon", "pointsEarned"]
    
    # Only convert columns that actually exist in the data
    for col in set(numeric_cols).intersection(set(items_lf.collect_schema().names())):
        items_lf = items_lf.with_columns(
            pl.col(col).str.replace("$", "").cast(pl.Float64, strict=False).alias(col)
        )
    
    return items_lf

file_path = "sample_data/receipts.json"
receipt_df = process_receipts_file(file_path)
receipt_df.collect()
# Out:
# '5ff1e1eb0a720f0523000575'

# %%
ex_df = pl.DataFrame(data)

ex_df
# Out:
# shape: (1_119, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ _id       ┆ bonusPoin ┆ bonusPoin ┆ createDat ┆ … ┆ rewardsRe ┆ rewardsRe ┆ totalSpen ┆ userId   │
# │ ---       ┆ tsEarned  ┆ tsEarnedR ┆ e         ┆   ┆ ceiptItem ┆ ceiptStat ┆ t         ┆ ---      │
# │ struct[1] ┆ ---       ┆ eason     ┆ ---       ┆   ┆ List      ┆ us        ┆ ---       ┆ str      │
# │           ┆ i64       ┆ ---       ┆ struct[1] ┆   ┆ ---       ┆ ---       ┆ str       ┆          │
# │           ┆           ┆ str       ┆           ┆   ┆ list[stru ┆ str       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ ct[33]]   ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ {"5ff1e1e ┆ 500       ┆ Receipt   ┆ {16096875 ┆ … ┆ [{"4011", ┆ FINISHED  ┆ 26.00     ┆ 5ff1e1ea │
# │ b0a720f05 ┆           ┆ number 2  ┆ 31000}    ┆   ┆ "ITEM NOT ┆           ┆           ┆ cfcf6c39 │
# │ 23000575" ┆           ┆ completed ┆           ┆   ┆ FOUND","2 ┆           ┆           ┆ 9c274ae6 │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆ 6.…       ┆           ┆           ┆          │
# │ {"5ff1e1b ┆ 150       ┆ Receipt   ┆ {16096874 ┆ … ┆ [{"4011", ┆ FINISHED  ┆ 11.00     ┆ 5ff1e194 │
# │ b0a720f05 ┆           ┆ number 5  ┆ 83000}    ┆   ┆ "ITEM NOT ┆           ┆           ┆ b6a9d73a │
# │ 2300056b" ┆           ┆ completed ┆           ┆   ┆ FOUND","1 ┆           ┆           ┆ 3a9f1052 │
# │ }         ┆           ┆ , bo…     ┆           ┆   ┆ ",…       ┆           ┆           ┆          │
# │ {"5ff1e1f ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ [{null,nu ┆ REJECTED  ┆ 10.00     ┆ 5ff1e1f1 │
# │ 10a720f05 ┆           ┆ pts       ┆ 37000}    ┆   ┆ ll,null,n ┆           ┆           ┆ cfcf6c39 │
# │ 2300057a" ┆           ┆ receipt   ┆           ┆   ┆ ull,false ┆           ┆           ┆ 9c274b0b │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆ ,nu…      ┆           ┆           ┆          │
# │ {"5ff1e1e ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ [{"4011", ┆ FINISHED  ┆ 28.00     ┆ 5ff1e1ea │
# │ e0a7214ad ┆           ┆ pts       ┆ 34000}    ┆   ┆ "ITEM NOT ┆           ┆           ┆ cfcf6c39 │
# │ a100056f" ┆           ┆ receipt   ┆           ┆   ┆ FOUND","2 ┆           ┆           ┆ 9c274ae6 │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆ 8.…       ┆           ┆           ┆          │
# │ {"5ff1e1d ┆ 5         ┆ All-recei ┆ {16096875 ┆ … ┆ [{"4011", ┆ FINISHED  ┆ 1.00      ┆ 5ff1e194 │
# │ 20a7214ad ┆           ┆ pts       ┆ 06000}    ┆   ┆ "ITEM NOT ┆           ┆           ┆ b6a9d73a │
# │ a1000561" ┆           ┆ receipt   ┆           ┆   ┆ FOUND","1 ┆           ┆           ┆ 3a9f1052 │
# │ }         ┆           ┆ bonus     ┆           ┆   ┆ ",…       ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ {"603cc06 ┆ 25        ┆ COMPLETE_ ┆ {16145941 ┆ … ┆ [{"B076FJ ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ 30a720fde ┆           ┆ NONPARTNE ┆ 47000}    ┆   ┆ 92M4","mu ┆           ┆           ┆ b8cfca11 │
# │ 100003e6" ┆           ┆ R_RECEIPT ┆           ┆   ┆ eller     ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆ austri…   ┆           ┆           ┆          │
# │ {"603d0b7 ┆ null      ┆ null      ┆ {16146133 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ 10a720fde ┆           ┆           ┆ 61873}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 1000042a" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603cf52 ┆ null      ┆ null      ┆ {16146076 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ 90a720fde ┆           ┆           ┆ 57664}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 10000413" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ {"603ce71 ┆ 25        ┆ COMPLETE_ ┆ {16146040 ┆ … ┆ [{"B076FJ ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ 00a7217c7 ┆           ┆ NONPARTNE ┆ 48000}    ┆   ┆ 92M4","mu ┆           ┆           ┆ b8cfca11 │
# │ 2c000405" ┆           ┆ R_RECEIPT ┆           ┆   ┆ eller     ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆ austri…   ┆           ┆           ┆          │
# │ {"603c4fe ┆ null      ┆ null      ┆ {16145653 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ a0a7217c7 ┆           ┆           ┆ 54962}    ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 2c000389" ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ }         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
def load_json_data(file_path: str) -> List[Dict[str, Any]]:
    """Load JSON data from file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def extract_data(data: List[Dict[str, Any]]) -> pl.DataFrame:
    """
    Extract all receipts data from the original JSON.
    This function automatically preserves all fields from the nested items.
    """
    # Initialize empty list to store all items
    all_items = []

    for receipt in data: 

        receipt_id = receipt.get("_id", {}).get("$oid", None)
        create_date = receipt.get("createDate").get("$date", None)
        date_scanned = receipt.get("dateScanned").get("$date", None)
        modify_date = receipt.get("modifyDate").get("$date", None)

        if 'finishedDate' not in receipt or receipt['finishedDate'] is None:
            finished_date = None
        else:
            finished_date = receipt.get("finishedDate").get("$date", None)

        if 'pointsAwardedDate' not in receipt or receipt['pointsAwardedDate'] is None:
            points_award_date = None
        else:
            points_award_date = receipt.get("pointsAwardedDate").get("$date", None)
        
        if 'purchaseDate' not in receipt or receipt['purchaseDate'] is None:
            purchase_date = None
        else:
            purchase_date = receipt.get("purchaseDate").get("$date", None)

        if not receipt_id:
            continue
            

        receipt_with_id = receipt.copy()
        receipt_with_id["_id"] = receipt_id
        receipt_with_id["createDate"] = create_date
        receipt_with_id["dateScanned"] = date_scanned
        receipt_with_id["finishedDate"] = finished_date
        receipt_with_id["modifyDate"] = modify_date
        receipt_with_id["pointsAwardedDate"] = points_award_date
        receipt_with_id["purchaseDate"] = purchase_date
        all_items.append(receipt_with_id)

    df = pl.from_dicts(all_items).lazy()

    # Convert int64 columns to datetime
    date_cols = [
        'createDate', 'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'purchaseDate'
    ]

    # Only convert columns that actually exist in the data
    for col in set(date_cols).intersection(set(df.collect_schema().names())):
        df = df.with_columns(
            pl.col(col).cast(pl.Datetime('ms')).alias(col)
        )

    # Drop unnecessary data
    df = df.drop(
        pl.col("rewardsReceiptItemList")
    )

    # Collect from lazyframe
    df = df.collect()

    return df


file_path = "sample_data/receipts.json"
data = load_json_data(file_path)
receipt_df = extract_data(data)
receipt_df
# Out:
# shape: (1_119, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ _id       ┆ bonusPoin ┆ bonusPoin ┆ createDat ┆ … ┆ purchased ┆ rewardsRe ┆ totalSpen ┆ userId   │
# │ ---       ┆ tsEarned  ┆ tsEarnedR ┆ e         ┆   ┆ ItemCount ┆ ceiptStat ┆ t         ┆ ---      │
# │ str       ┆ ---       ┆ eason     ┆ ---       ┆   ┆ ---       ┆ us        ┆ ---       ┆ str      │
# │           ┆ i64       ┆ ---       ┆ datetime[ ┆   ┆ i64       ┆ ---       ┆ str       ┆          │
# │           ┆           ┆ str       ┆ ms]       ┆   ┆           ┆ str       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 5ff1e1eb0 ┆ 500       ┆ Receipt   ┆ 2021-01-0 ┆ … ┆ 5         ┆ FINISHED  ┆ 26.00     ┆ 5ff1e1ea │
# │ a720f0523 ┆           ┆ number 2  ┆ 3         ┆   ┆           ┆           ┆           ┆ cfcf6c39 │
# │ 000575    ┆           ┆ completed ┆ 15:25:31  ┆   ┆           ┆           ┆           ┆ 9c274ae6 │
# │           ┆           ┆ , bo…     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 5ff1e1bb0 ┆ 150       ┆ Receipt   ┆ 2021-01-0 ┆ … ┆ 2         ┆ FINISHED  ┆ 11.00     ┆ 5ff1e194 │
# │ a720f0523 ┆           ┆ number 5  ┆ 3         ┆   ┆           ┆           ┆           ┆ b6a9d73a │
# │ 00056b    ┆           ┆ completed ┆ 15:24:43  ┆   ┆           ┆           ┆           ┆ 3a9f1052 │
# │           ┆           ┆ , bo…     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 5ff1e1f10 ┆ 5         ┆ All-recei ┆ 2021-01-0 ┆ … ┆ 1         ┆ REJECTED  ┆ 10.00     ┆ 5ff1e1f1 │
# │ a720f0523 ┆           ┆ pts       ┆ 3         ┆   ┆           ┆           ┆           ┆ cfcf6c39 │
# │ 00057a    ┆           ┆ receipt   ┆ 15:25:37  ┆   ┆           ┆           ┆           ┆ 9c274b0b │
# │           ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 5ff1e1ee0 ┆ 5         ┆ All-recei ┆ 2021-01-0 ┆ … ┆ 4         ┆ FINISHED  ┆ 28.00     ┆ 5ff1e1ea │
# │ a7214ada1 ┆           ┆ pts       ┆ 3         ┆   ┆           ┆           ┆           ┆ cfcf6c39 │
# │ 00056f    ┆           ┆ receipt   ┆ 15:25:34  ┆   ┆           ┆           ┆           ┆ 9c274ae6 │
# │           ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 5ff1e1d20 ┆ 5         ┆ All-recei ┆ 2021-01-0 ┆ … ┆ 2         ┆ FINISHED  ┆ 1.00      ┆ 5ff1e194 │
# │ a7214ada1 ┆           ┆ pts       ┆ 3         ┆   ┆           ┆           ┆           ┆ b6a9d73a │
# │ 000561    ┆           ┆ receipt   ┆ 15:25:06  ┆   ┆           ┆           ┆           ┆ 3a9f1052 │
# │           ┆           ┆ bonus     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 603cc0630 ┆ 25        ┆ COMPLETE_ ┆ 2021-03-0 ┆ … ┆ 2         ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ a720fde10 ┆           ┆ NONPARTNE ┆ 1         ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 0003e6    ┆           ┆ R_RECEIPT ┆ 10:22:27  ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ 603d0b710 ┆ null      ┆ null      ┆ 2021-03-0 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ a720fde10 ┆           ┆           ┆ 1 15:42:4 ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 00042a    ┆           ┆           ┆ 1.873     ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ 603cf5290 ┆ null      ┆ null      ┆ 2021-03-0 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ a720fde10 ┆           ┆           ┆ 1 14:07:3 ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 000413    ┆           ┆           ┆ 7.664     ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ 603ce7100 ┆ 25        ┆ COMPLETE_ ┆ 2021-03-0 ┆ … ┆ 2         ┆ REJECTED  ┆ 34.96     ┆ 5fc961c3 │
# │ a7217c72c ┆           ┆ NONPARTNE ┆ 1         ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 000405    ┆           ┆ R_RECEIPT ┆ 13:07:28  ┆   ┆           ┆           ┆           ┆ a077dd33 │
# │ 603c4fea0 ┆ null      ┆ null      ┆ 2021-03-0 ┆ … ┆ null      ┆ SUBMITTED ┆ null      ┆ 5fc961c3 │
# │ a7217c72c ┆           ┆           ┆ 1 02:22:3 ┆   ┆           ┆           ┆           ┆ b8cfca11 │
# │ 000389    ┆           ┆           ┆ 4.962     ┆   ┆           ┆           ┆           ┆ a077dd33 │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df.join
# Out:
# ---------------------------------------------------------------------------
# SQLInterfaceError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.sql(
#       2     """
#       3         SELECT
#       4             date_trunc('m', "createDate")
#       5         FROM
#       6             self
#       7     """
#       8 )
#
# File ~/Documents/code/fetch_analytics_engineering/fetch-analytics-engineer/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py:5664, in DataFrame.sql(self, query, table_name)
#    5662 name = table_name if table_name else "self"
#    5663 ctx.register(name=name, frame=self)
# -> 5664 return ctx.execute(query)
#
# File ~/Documents/code/fetch_analytics_engineering/fetch-analytics-engineer/.venv/lib/python3.12/site-packages/polars/sql/context.py:437, in SQLContext.execute(self, query, eager)
#     356 def execute(
#     357     self, query: str, *, eager: bool | None = None
#     358 ) -> LazyFrame | DataFrame:
#     359     """
#     360     Parse the given SQL query and execute it against the registered frame data.
#     361
#    (...)
#     435     └────────┴─────────────┴─────────┘
#     436     """
# --> 437     res = wrap_ldf(self._ctxt.execute(query))
#     438     return res.collect() if (eager or self._eager_execution) else res
#
# SQLInterfaceError: unsupported function 'date_trunc'

# %%
def load_json_data(file_path: str) -> List[Dict[str, Any]]:
    """Load JSON data from file with error handling."""
    try:
        with open(file_path, 'r') as file:
            return json.load(file)
    except (json.JSONDecodeError, FileNotFoundError) as e:
        print(f"Error loading JSON data: {e}")
        return []

def extract_nested_date(receipt: Dict[str, Any], field_name: str) -> json[str]:
    """Extract nested date value or return None if not present."""
    if field_name not in receipt or receipt[field_name] is None:
        return None
    return receipt.get(field_name, {}).get("$date", None)

def extract_data(data: List[Dict[str, Any]]) -> pl.DataFrame:
    """
    Extract all receipts data from the original JSON.
    This function automatically preserves all fields from the nested items.
    """
    # Initialize empty list to store all items
    all_items = []

    for receipt in data:
        receipt_id = receipt.get("_id", {}).get("$oid", None)
        
        # Skip records without ID
        if not receipt_id:
            continue
            
        # Extract all date fields with helper function
        create_date = receipt.get("createDate", {}).get("$date", None)  # Required field
        date_scanned = receipt.get("dateScanned", {}).get("$date", None)  # Required field
        modify_date = receipt.get("modifyDate", {}).get("$date", None)  # Required field
        finished_date = extract_nested_date(receipt, "finishedDate")
        points_award_date = extract_nested_date(receipt, "pointsAwardedDate")
        purchase_date = extract_nested_date(receipt, "purchaseDate")

        # Create updated receipt with extracted date values
        receipt_with_id = {**receipt}  # Create a copy of the receipt
        # Update with extracted values
        date_updates = {
            "_id": receipt_id,
            "createDate": create_date,
            "dateScanned": date_scanned,
            "finishedDate": finished_date,
            "modifyDate": modify_date,
            "pointsAwardedDate": points_award_date,
            "purchaseDate": purchase_date
        }
        receipt_with_id.update(date_updates)
        
        # Remove the nested item list to create separate dataframe
        if "rewardsReceiptItemList" in receipt_with_id:
            receipt_with_id.pop("rewardsReceiptItemList")
            
        all_items.append(receipt_with_id)

    # Create dataframe from processed items
    if not all_items:
        return pl.DataFrame()  # Return empty dataframe if no items

    df = pl.from_dicts(all_items).lazy()

    # Convert int64 columns to datetime
    date_cols = [
        'createDate', 'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'purchaseDate'
    ]

    # Only convert columns that actually exist in the data
    existing_date_cols = set(date_cols).intersection(set(df.collect_schema().names()))
    
    if existing_date_cols:
        df = df.with_columns([
            pl.col(col).cast(pl.Datetime('ms')).alias(col)
            for col in existing_date_cols
        ])

    # Collect from lazyframe
    return df.collect()


file_path = "sample_data/receipts.json"
data = load_json_data(file_path)
receipt_df = extract_data(data)
receipt_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 10
#       7         print(f"Error loading JSON data: {e}")
#       8         return []
# ---> 10 def extract_nested_date(receipt: Dict[str, Any], field_name: str) -> Optional[str]:
#      11     """Extract nested date value or return None if not present."""
#      12     if field_name not in receipt or receipt[field_name] is None:
#
# NameError: name 'Optional' is not defined
